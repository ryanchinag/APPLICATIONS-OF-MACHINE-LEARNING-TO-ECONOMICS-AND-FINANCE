# %% [markdown]
# 思考:
# 決策概念
# 臉書推播AD
# 學習連竄性反應，找出來更適應的MODEL
# 自然語言學習
# 神經網絡系統
# ...
# Numpy 數字處理
# Pandas 資料庫
# Matplotlib,Seaborn 圖像化
# SciKit-Learn
#
# 如何安裝套件?
# pip install packagename<=命令提示字元
# !pip install packagename<=python
#
# 指令運作
# Ctrl+z 上一步
# Sh+Enter 下一行In
# Alt+Enter
# 增加新In
# Ctrl+S 儲存
# Ctrl+c 存且離
#
# 找路徑
# import os
# os.getcwd()
#
# 字體變大
# #
# ##
# ###
# ####
# #####
# ....
#
# 關鍵字保留
#
# 縮排嚴格執行
# if....:
#     print()...
# else:
#     print()...
#
# 編譯與直譯
# 編譯:使用編譯器做轉換
# 直譯:直接運行
#
# print("Hello world")
#
# 數學符號
# +
# -
# *
# /
# %<=取餘數
# **<=次方
# //<=取商數
#
# 定義變數
# x = 10
# y = 20
#
# out = x*y
#
# print(out)
#
# 變數命名規則:
#     不可使用關鍵字，內建函式，內建類別
#     可用Aa_欸做開頭，內容可以亦可為數字
#
# 物件資料型態
# 數(numeric)
#     int
#     float
#     Booleans布林值
# 字串(string)
#     str
# type()找型態
#
# 運算子
#     == 相等
#     != 不等
#     >  大於
#     >= 大於等於
#     <  小於
#     <= 小於等於
#     & AND
#     | or
#
# Sequences
#     list串列
#     l = [....]
#     使用[]
#     始於0位置
#     可用[-1]找最後位置
#     也可針對某項直接取代
#
# Object s Type 物件的資料型態
#     小括號<=不可變更
#     中括號<=可變更
# t
# set.
# dict
#
# .lower
# .upper
# .split
# .split('!')
# .join 結合
